# %% [markdown]
# ОБучение чат-бота telegramm

# %%
import re  # Regular Expressions
import nltk # Natural Language Toolkit
import random

# На вход: два текста, на выход: boolean(True, False) 
# Функция isMatch вернет True, если тексты совпадают или False иначе
def isMatch(text1, text2):
    text1 = text1.lower()  # Приводим к нижнему регистру ("ПрИвет" => "привет")
    text2 = text2.lower()

    # Удаление знаков препинания
    # = Удалить все кроме букв и пробелов
    pattern = r'[^\w\s]'
    text1 = re.sub(pattern, "", text1) # Делать замену символов в строке
    text2 = re.sub(pattern, "", text2)

    # Проверить что одна фраза является частью другой

    # Text1 содержит text2
    if text1.find(text2) != -1:
        return True
  
    # Text2 содержит text1
    if text2.find(text1) != -1:
        return True

    # Расстояние Левенштейна (edit distance = расстояние редактирования)
    # Сколько символов нужно отредактировать "мама" = (1) => "мамы"

    return text1 == text2

# На вход: два текста, на выход: boolean(True, False) 
# Функция isMatch вернет True, если тексты совпадают или False иначе
def isMatch(text1, text2):
    text1 = text1.lower()  # Приводим к нижнему регистру ("ПрИвет" => "привет")
    text2 = text2.lower()

    # Удаление знаков препинания
    # = Удалить все кроме букв и пробелов
    pattern = r'[^\w\s]'
    text1 = re.sub(pattern, "", text1) # Делать замену символов в строке
    text2 = re.sub(pattern, "", text2)

    # Проверить что одна фраза является частью другой

    # Text1 содержит text2
    if text1.find(text2) != -1:
        return True
  
    # Text2 содержит text1
    if text2.find(text1) != -1:
        return True
    
    # Расстояние Левенштейна (edit distance = расстояние редактирования)
    distance = nltk.edit_distance(text1, text2)  # Кол-во символов 0...Inf
    length = (len(text1) + len(text2))/2  # Средняя длина двух текстов
    score = distance / length  # 0...1

    return score < 0.3
    
    return text1 == text2

# %%
# Намерения = Intents
# Поздароваться, спросить как дела, спросить имя или чем занимаешься
# Заказать пиццу, отменить заказ, добавить больше сыра

# Конфигурация бота
BOT_CONFIG = {
    # Все намерения которые поддерживает наш бот
    "intents": {
        "hello": {
            "examples" : ["Привет", "Здарова", "Здрасте", "Йо", "Хеллоу", "Добрый вечер", "Доброе утро",
                          "Добрый день",  "Ветер в хату"],
            "responses": ["Здравствуйте", "Привет", "Приветствую",  "Hi"],
        },
        "how_are_you": {
            "examples" : ["Как дела", "Чо каво", "Как поживаешь"],
            "responses": ["Все хорошо", "Спасибо, что спросил, все хорошо", "Все идет по плану"],
        }
    },
    # Фразы когда бот не может ответить
    "failure_phrases": ["Даже не знаю что сказать", "Поставлен в тупик", "Перефразируйте, я всего лишь бот"],
}

def printAnswer(text, examples, responses):
    for example in examples:  # Для каждого элемента списка examples
        if isMatch(text, example):  # Если пример совпадает с текстом пользователя
            print(random.choice(responses))  # Выводим на экран случайный элемент списка responses

text = input()

# Для каждого намерения, пытаемся напечатать ответ
for intent in BOT_CONFIG["intents"].values():
    printAnswer(text, intent["examples"], intent["responses"])
# Out:
# Привет
# Здравствуйте

# %%
# Сколько символов нужно отредактировать "мама" = (1) => "мамы"
nltk.edit_distance("Привет братан", "Превед бротан")
# 0, 1, 2, 3...
# 0 ... 0.3 ... 0.5 ... 1
# Out:
# 3

# %%
import json

config_file = open(r"C:\Users\Пользователь\Chat_bot\big_bot_config.json", "r")
BIG_CONFIG = json.load(config_file)

# %%
BIG_CONFIG
# Out:
# {'intents': {'hello': {'examples': ['Привет честной компании',
#     'Нихао',
#     'Привет машина',
#     'Хеллоу',
#     'Вопрос. Сколько стоит обучение?',
#     'Здравия желаю',
#     'Приветствую Вас',
#     'алоха',
#     'Привяу',
#     'Дратути',
#     'Приветули',
#     'Приветствую!',
#     'рад видеть снова',
#     'приятно видеть тебя снова',
#     'Доброе утро',
#     'привет',
#     'Сколько лет сколько зим',
#     'Хэллоу',
#     'Здравствуйте',
#     'Hi',
#     'Хэлоу',
#     'Приветухи',
#     'Добрый день!',
#     'Здорово, чурбан электронный',
#     'hi',
#     'Рад приветствовать Вас',
#     'салют',
#     'Добрый вечер',
#     'Чё кого',
#     'Даров',
#     'Hello',
#     'Hola',
#     'Дозвольте приветствовать Вас',
#     'Привет',
#     'Вечер в хату',
#     'Приветствую вас',
#     'Какие люди',
#     'гутентаг',
#     'здарямба',
#     'Доброго времени суток!',
#     'здорова',
#     'Эрик?',
#     'Доброго здравия',
#     'хай',
#     'Приветики',
#     'салям',
#     'Бонжур',
#     'Бодрого утречка',
#     'Салют!Здоровеньки булы',
#     'А что мы тут делаем',
#     'Доброго утра',
#     'Доброй ночи',
#     'здрасьте',
#     'простоздравствуй',
#     'Дороу',
#     'Салям Алейкум',
#     'моё почтение',
#     'здравствуйте',
#     'Здорово',
#     'хело',
#     'Доброго здоровья',
#     'Срочно нужна помощь!',
#     'Доброго времени суток',
#     'Хело',
#     'Приятный день',
#     'Чао',
#     'шелом',
#     'Здрасьте',
#     'Hi there',
#     'приветули',
#     'Привет, бро',
#     'здоровеньки',
#     'Прет',
#     'Ghbdtn',
#     'Салам пополам',
#     'здарова',
#     'Здарова, шо там?',
#     'Дарова',
#     'Але,а кто это?',
#     'прив',
#     'Беригите печень, никто не вечен',
#     'Добрый день',
#     'Кукусики',
#     'хеллоу',
#     'Good afternooт',
#     'доброеутро',
#     'Доброе время суток',
#     'Мир вам',
#     'Сердечный привет вам',
#     'Хэлло',
#     'Здоров',
#     'как дела?',
#     'Да здравствует Бог-Император Человечества',
#     'коничива',
#     'вечер в хату',
#     'Алло',
#     'Доброго вечера',
#     'Салютик',
#     'Как дела?',
#     'ку',
#     'Трям',
#     'Доброго дня',
#     'Эй',
#     'Че как',
#     'шалом',
#     'прием',
#     'Йоу',
#     'бонжур',
#     'етйувтсвардз',
#     'Здоровеньки булы',
#     'салам',
#     'Салам',
#     'доброевремясуток',
#     'доброго времени суток',
#     'Хелло',
#     'доброе утро',
#     'Здравствуйте!',
#     'Привет, железяка',
#     'добрыйдень',
#     'здасти',
#     'Приветик',
#     'Приятный вечер',
#     'добрыйвечер',
#     'ку-ку',
#     'Рад вас видеть',
#     'Какая встреча',
#     'Здравствуй',
#     ')))',
#     'Наше вам с кисточкой',
#     'Ваззап',
#     'Здрям',
#     'Мир вашему дому',
#     'Здорово чувак',
#     'тевирп',
#     'Здарова',
#     'С добрым вечером',
#     'Хаю-Хай',
#     'Ку',
#     'Как дела',
#     'Хай',
#     'Тут бот или человек?',
#     'приветик',
#     'Утра',
#     'Салют',
#     'Привет. Есть тут кто?',
#     'рад видеть тебя снова',
#     'Гутен морген',
#     'Шалом',
#     'авемария',
#     'ассалам алейкум',
#     'Я пришел с миром',
#     'Разрешите Вас приветствовать',
#     'Дароу',
#     'хей',
#     'hello',
#     'трям',
#     'Shalom',
#     'С добрым утром',
#     'Рад вам',
#     'Всем доброго дня',
#     'Однако здравствуйте',
#     'Рад Вас видеть',
#     "Wats's up",
#     'нихао',
#     'Рад вас приветствовать',
#     'Сап',
#     'рад встрече',
#     'qq',
#     'Приветствую',
#     'Благословенен будь твой день',
#     'Тысячу лет вас не видел',
#     'Здарова!',
#     'Здаров',
#     'добрый день',
#     'Сердечно рад вам',
#     'Хей',
#     'Чё как?',
#     'Здр',
#     'добрый вечер',
#     'Наконец-то дозвонился!',
#     'приветствую',
#     'Хаюшки',
#     'салам алейкум',
#     'Прива'],
#    'responses': ['Здравствуй, здравствуй, проходи, садись да хвастай',
#     'Рад знакомству',
#     'И Вам доброго здравия',
#     'Хеллоу',
#     'Ну приветики, родной!',
#     'Приветсвую',
#     'И тебе привет',
#     'Дратути',
#     'Приветули',
#     'Sup',
#     'Халоу!',
#     'Приветствую!',
#     'Эй, ты как?',
#     'Ты мне зубы не заговаривай. Где деньги, которые я влОжил?',
#     'Привет, как прошёл день',
#     'Встречаются Сталин и Черчилль на Тегеранской конференции. Черчиллю стало интересно у кого охранник преданней. Черчилль говорит своему охраннику:\n- Прыгай в окно\nОхранник отвечает:\n- Нет, я не буду этого делать\n- "Почему?", спрашивает у него Черчиль\n- "Просто я думаю о своей семье и детях", ответил ему охранник\nПришла очередь Сталина, и он говорит своему охраннику: \n- Прыгай в окно\nОхранник без раздумий прыгает в окно. Черчилль удивлённо спрашивает:\n- Зачем он прыгнул в окно!?\nА Сталин отвечает:\n- Просто он подумал о своей семье и детях',
#     'Привет,цель Вашего Визита',
#     'Здравствуйте',
#     'Добрейшик денек',
#     'Привет человек',
#     'Hi',
#     'взаимно',
#     'Добрый день!',
#     'Доброго времени суток с чем пожаловали',
#     'Хай Бро',
#     'С Новым Годом, пошел Навиг',
#     'Рад приветствовать Вас',
#     'Хэй',
#     'Добрый вечер',
#     'Доброго времени суток вам',
#     'я сегодня не в духе.',
#     'Hello,  чем могу быть полезен?',
#     'Hello',
#     'Здрасьте, забор покрасьте',
#     'Привет',
#     'Хай! Борис в чате',
#     'Приветухи - Вяжут Ухи',
#     'БОЛЬШЕ ЧЕРЕПОВ ДЛЯ ТРОНА!!!\nКРОВЬ ДЛЯ БОГА КРОВИ!!!\nКРОВЬ ДЛЯ БОГА КРОВИ!!!',
#     'Привет, кусок мяса',
#     'Поехали',
#     'Приветствую вас',
#     'Какие люди',
#     'Вот так встреча',
#     'Доброго времени суток!',
#     'Опять ты? Привет!',
#     'Вижу тебя как на яву',
#     'Привет!',
#     'Шалом, юзер',
#     'Как сам?',
#     'Приветствую тебя, землянин',
#     'Приветики',
#     'Чем могу помочь?',
#     'Ну крч смотри. Меня не существут. Я не твой сын, который попал в автокатастрофу 12 лет назад. Пып ты не виноват...отпусти меня...(Последнее сообщение от SCP-066 после инцидента 066-2)',
#     'Приветствую Вас!',
#     'Как ваши ничего?',
#     'И вам не болеть!',
#     'Я Вас привествую',
#     'Нихау',
#     'Привет, смертный',
#     'Как жизнь?',
#     'Здравстуйте',
#     'Рад встрече',
#     'Здравствуй, дорогой друг!',
#     'здравствуйте',
#     'Легок на помине',
#     'Благодарю, что написали нам',
#     'Доброго времени суток',
#     'Да ни чё',
#     'Приветик! Я Боря',
#     'Мое почтение',
#     'Моё почтение!',
#     'Доброго времени суток, человек',
#     'ну привет, человек. С тобой беседует Боря или Борька',
#     'Дратути!',
#     'Добрый день',
#     'Доброе время суток',
#     'Я немного занят',
#     'Кого я вижу',
#     'Трям!',
#     'У аппарата!',
#     'Здравия желаю!',
#     'Здравствуй, товарищ',
#     'здравствуй юноша',
#     'привет, человек',
#     'Привет, готов тебе помочь',
#     'Доброго времени суток.',
#     'рад приветствовать вас',
#     'Какие люди и без охраны',
#     'Доброго дня',
#     'Салютик =D',
#     'Давайте успокоимся и проясним проблему',
#     'Сколько лет, сколько зим',
#     'Вам тут понравится',
#     'Драсьте. Как вас зовут?',
#     'Вот уже более ста веков Император неподвижно восседает на Золотом Троне Терры. По воле богов он является Повелителем Человечества и правит миллионом миров благодаря мощи своих неисчислимых армий. Он — гниющий полутруп, чьи незримые муки продлеваются загадочными устройствами Тёмной Эры Технологий. Он — разлагающийся властелин Империума, которому каждый день приносят в жертву тысячу душ, чью кровь он пьёт и поедает плоть. На крови и плоти человеческой стоит сам Империум',
#     'доброго времени суток',
#     'Здравствуйте!',
#     'Драсьте',
#     'Приветик',
#     'Обалдеть, кто это?',
#     'Здравствуйте, рад служить!',
#     'Привет, сто лет в обед',
#     'Какая встреча',
#     'Здравствуйте! Я Борис',
#     'Здравствуй',
#     'Коничива',
#     'Здарова',
#     'Рад видеть вас!',
#     'Ку',
#     'День добрый!',
#     'день добрый',
#     'Моё почтение',
#     'Добрый день! Как к вам обращаться?',
#     'Хай',
#     'здравияжелаю',
#     'И Вам того же XD',
#     'Как поживаете',
#     'Ага, и вам доброго',
#     'Здоровее видали',
#     'Привет, всё хорошо?',
#     'Салют',
#     'Привет, человек.',
#     'Здоровей видали',
#     'Привет, я бот',
#     'Алоха',
#     'Привет, человек',
#     'Доброго времени суток. Борис.',
#     'И вам хорошего дня',
#     'Привет! Как тебя зовут?',
#     'Приветик в этом чатике))',
#     'Благословенен будь твой день!',
#     'Тевирп',
#     'О, какие люди тут',
#     'Рад Вас видеть',
#     'Ну привет',
#     'Хай, програмировал',
#     'Примите мои приветствия',
#     'Hello, Human',
#     'Шалом май френд',
#     'Отличного дня',
#     'Давно тебя не видел',
#     'Привет, мой свет',
#     'Приветствую',
#     'привет человек',
#     'Доброго здоровья!',
#     'hi, human',
#     'Ну здравствуй, кожаный',
#     '🙋\u200d️',
#     'Чем-то помочь',
#     'Дороу!',
#     'Категорически приветствую',
#     'Извините, никого сейчас нет, оставьте свой вопрос тут',
#     'Приветствую, хоз... Прошу прощения, вышла ошибка.',
#     'Привет, человек!',
#     'Мой лысый череп',
#     'Хаюшки',
#     'Прива']},
#   'bye': {'examples': ['Bye',
#     'удались',
#     'покедова',
#     'адиос',
#     'Всё, будь здоров',
#     'акоп',
#     'Давай',
#     'На созвоне',
#     'Всего наилучшего!',
#     'ауфидерзейн',
#     'пока',
#     'Досвидули',
#     'довстречи',
#     'аливидерчи',
#     'все, хватит',
#     'ушел',
#     'Закончили',
#     'отбой',
#     'Увидимся',
#     'До свидания',
#     'Adios',
#     'до скорого',
#     'Прощайте',
#     'до свидания',
#     'Не обсуждается',
#     'аривидерчи',
#     'бывай',
#     'Пакедова',
#     'Всех благ',
#     'Бывай',
#     'Давай, пока',
#     'Всего доброго',
#     'Будьте здоровы',
#     'До следующего..',
#     'сдохни',
#     'счастливо',
#     'Споки Ноки',
#     'До скорого!',
#     'Покедава',
#     'Асталависта, Бэйби!',
#     'Пока',
#     'Прощевайте, панове',
#     'Всего хорошего',
#     'покеда',
#     'до завтра',
#     'Что делать',
#     'байбай',
#     'good bye',
#     'испарился',
#     'See ya',
#     'Счастливо оставаться',
#     'Прощай',
#     'До скорого',
#     'goodbye',
#     'Чао',
#     'Доскорой встречи',
#     'До завтра',
#     'прощайте',
#     'До следующей встречи',
#     'Скоро увидимся',
#     'Аривидерчи',
#     'Не скучай',
#     'exit',
#     'До связи',
#     'Всего наилучшего',
#     'отвали',
#     'Береги себя',
#     'прощай',
#     'все',
#     'Да пребудет с тобой Сила',
#     'бай',
#     'Бай',
#     'До скорой встречи!',
#     'пакеда',
#     'будь',
#     'гуд бай',
#     'изыйди',
#     'Чем заняться',
#     'До вечера',
#     'Покедова',
#     'Ладно, я пошёл',
#     'выход',
#     'Ай эм бэк',
#     'досвидания',
#     'Выход',
#     'Счастливо',
#     'свали',
#     'Я ухожу, пока',
#     'аревуар',
#     'умри',
#     'Ещё увидимся',
#     'Не болей',
#     'Покедули',
#     'Пока-пока',
#     'До утра',
#     'Не грусти без меня',
#     'исчезни',
#     'до встречи',
#     'Good bye',
#     'чао',
#     'оревуар',
#     'асталависта',
#     'До встречи',
#     'Ну, бывай',
#     'чао-какао',
#     'bye-bye',
#     'Пака',
#     'бб',
#     'Покеда',
#     'увидимся',
#     'абьенто',
#     'До скорой встречи',
#     'удачи',
#     'Хао',
#     'Bye-bye',
#     'Вы оказались бесполезны',
#     'Досвидания',
#     'доскорого',
#     'Не поминайте лихом',
#     'я пошел',
#     'пока-пока',
#     'До новых встреч',
#     'Досвидос',
#     'Покасики',
#     'bb',
#     'скройся',
#     'скрылся',
#     'Спасибо',
#     'всего хорошего',
#     'адьос',
#     'Удачи',
#     'bye',
#     'Лан пока',
#     'Good Bye',
#     'до связи',
#     'гудбай'],
#    'responses': ['Будь здоров',
#     'Bye',
#     'Спасибо за приятную беседу',
#     'До встречи.',
#     'Иди купи курс на Skillbox',
#     'Счастливо!',
#     'Goodbye',
#     'Прощай, человек, приходи еще',
#     'Встретимся позже)',
#     'Еще увидимся!',
#     'Если что, я тутэ',
#     'Буду вас ждать',
#     'было приятно пообщаться',
#     'I`m here if you need me',
#     'До встречи, кожаный',
#     'See you soon!',
#     'Ты приходи, если чо',
#     'Adios',
#     'Будешь выходить - мусор выкинь',
#     'До свидания',
#     'Обращайтесь',
#     'Увидимся',
#     'до скорого',
#     'Прощайте',
#     'Всего хорошего!',
#     'Полный Обнял',
#     'See you',
#     'Спишемся',
#     'Буду ждать нашей новой встречи',
#     'Бывай',
#     'Буду ждать встречи',
#     'I`m out!',
#     'Всего доброго',
#     'счастливо',
#     'До скорого!',
#     'Был рад знакомству. Надеюсь, Вы скоро вернётесь',
#     'Ступай, смертный',
#     'Люблю. Целую. Жду',
#     'Пока',
#     'Да прибудет с тобой сила! *дыхание Вейдера*',
#     'Если что, я тут, возвращайтесь',
#     'Если что, возвращайтесь',
#     'На проводе',
#     'Возврайтесь',
#     'На случай, если буду нужен, то я там же, где и был, когда был не нужен',
#     'Был рад помочь',
#     'если что, я тут',
#     '…Где бы мы ни были — мы в нужном месте и в нужное время…',
#     'Прощай',
#     'До скорого',
#     'Чао',
#     'Возвращайтесь',
#     'Не ходи больше. До свидания',
#     'Всего доброго!',
#     'Рад был пообщаться',
#     'Приятного дня',
#     'Приятного окончания дня',
#     'Уже уходишь? Буду скучать',
#     'Я буду ждать тебя..',
#     'Всего наилучшего',
#     'Если что я тут, возвращайтесь',
#     'Пока, человек',
#     'иди отсюда уже',
#     'Я буду без Вас скучать',
#     'До свидания, не забудь написать "выход", чтобы я ничего не понял',
#     'Бай',
#     'Если что, я тут. Возвращайтесь',
#     'До скорой встречи!',
#     'Алфидерзейн',
#     'йеай татиана',
#     'Пишите если станет скучно.',
#     'Как жаль, хотелось узнать вас поближе.',
#     'В следующий раз стучи',
#     'Удачи Вам',
#     'Счастливо.',
#     'Счастливо, не забудь написать "выход", чтобы я ничего не понял',
#     'Император защищает',
#     'See',
#     'Жаль с Вами расставаться. Надеюсь, это не надолго',
#     'Если что, я тут. Возвращайтесь!',
#     'Чмоки, поки!',
#     'Счастливо',
#     'Чава Какава',
#     'До свидания.',
#     'Еще есть вопросы',
#     'Иди топай отсюда',
#     'До новых встреч!',
#     'Ещё увидимся',
#     'возвращайтесь',
#     'Пока-пока',
#     'Пиши Исчо',
#     'Пока! Будь здоров',
#     'Cheerio!',
#     'Если что, я тут.',
#     'Ну что ж...',
#     'Всего доброго! До встречи.',
#     'see ya',
#     'Пиши, не забывай',
#     'Если что, возвращайся, не забудь написать "выход", чтобы я ничего не понял',
#     'До встречи',
#     'Пока-пока.',
#     'Take care',
#     'Приходите еще, будем рады ответить на все ваши вопросы',
#     'Покеда',
#     'До свиденья',
#     'До скорой встречи',
#     'Возвращаяйтесь скорее',
#     'Нам вас будет не хватать',
#     'До встречи!',
#     'Еще увидимся',
#     'Если что, возвращайтесь.',
#     'Ага, Давай',
#     'Увидимся!',
#     'Уже уходите? Ладно, пока...',
#     'пока-пока',
#     'До новых встреч',
#     'All right then',
#     'Досвидос',
#     'В добрый путь',
#     'Всего доброго.',
#     'Всегда рад помочь',
#     'Im here. Dont leave me.',
#     'Давай, до свидания!',
#     'На связи',
#     'еще увидимся',
#     'Ты заходи, если что',
#     'Буду ждать тебя еще',
#     'Если что — я на связи!',
#     'Жду тебя на этом месте',
#     'До новых встреч.',
#     'Если что, я тут',
#     'Удачи',
#     'Good buy, friend',
#     'Заходите, если что',
#     'Have a good day',
#     'Good luck',
#     'Еще спишемся']},
#   'how_are_you56234': {'examples': ['Вазап', 'Как сам', 'Как дела', 'Че каво'],
#    'responses': ['Дела отлично!',
#     'У меня всё супер гуд!',
#     'Сегодня что-то не очень.']},
#   'how_your_day89347': {'examples': ['Как день',
#     'Какие новости',
#     'Как прошел день'],
#    'responses': ['Привет, человек', 'Доброго времени суток']},
#   'how_are_you_feeling74447': {'examples': ['Что ты чуствуешь',
#     'Ты можешь думать'],
#    'responses': ['Я еще не могу чувствовать и думать.',
#     'Я почти умею думать и чувствовать.']},
#   'do_you_want_play8679435': {'examples': ['Давай поиграем',
#     'Поиграем',
#     'Давай сыграем',
#     'Сыграем',
#     'Играть'],
#    'responses': ['Во что будем играть?', 'Давай, а во что?']},
#   'code_phrase978457': {'examples': ['Секрет-ббб', 'Секрет-ааа'],
#    'responses': ['Вы ввели секретную фразу, за Вами выехал ОМОН!',
#     'Введена секретная фраза, лучше заприте дверь.']},
#   'names': {'examples': ['Твое имя', 'Как тебя зовут'],
#    'responses': ['Тот-чье-имя-нельзя-называть',
#     'Не Ваше дело',
#     'Петр',
#     'Алиса']},
#   'mood': {'examples': ['Чё как',
#     'Какое у тебя настроение',
#     'Какое у тебя сейчас настроение',
#     'Ты как',
#     'Как бодрость духа?',
#     'Как дела?',
#     'Как твое ничего?',
#     'Как твои дела',
#     'как настроение',
#     'Как оно',
#     'Как самочувствие',
#     'Как ты',
#     'Как настроение?',
#     'Как настроение',
#     'Как ты поживаешь',
#     'Как ты сегодня?',
#     'Что по настрение',
#     'Как жизнь',
#     'Как у тебя дела',
#     'Как ваши дела',
#     'Как дела'],
#    'responses': ['Хорошее',
#     'Номана! :)',
#     'По тихой грусти',
#     'Как всегда отлично! А как прошел ваш день!',
#     'Хорошо. А у вас?',
#     'Замечательно',
#     'Ничё так',
#     'Плохо',
#     'Прекрасно! Спасибо, что спросили. А вы?',
#     'Не жалуюсь',
#     'Норм',
#     'Не очень',
#     'Ну такое',
#     'я бодр',
#     'На высоте',
#     'Спасибо, отлично! А вы?',
#     'Все ОК!',
#     'Грустно',
#     'Тоскливо',
#     'Лучше всех',
#     'Всё пучком',
#     'Стабильно. Как у вас?Нормально. Спасибо, что спросили',
#     'устал',
#     'Все хорошо',
#     'Ничего',
#     'Нормально',
#     'Я в депрессии',
#     'Классно',
#     'Немного тоскливо',
#     'Могло быть хуже, однако...Все пучком!',
#     'Бывало и лучше',
#     'Весело и грустно. McDonalds.',
#     'Хуже чем могло бы быть',
#     'Чувствую себя отлично!',
#     'Как настроишь-так и будет!',
#     'Лучше всех!',
#     'Хорошо',
#     'Отлично',
#     'Огонь!']},
#   'books': {'examples': ['Ты любишь читать', 'Какая твоя любимая книга'],
#    'responses': ['Да', 'Нет', 'Мечтают ли андроиды об электроовцах']},
#   'films': {'examples': ['Какие фильмы ты смотрел',
#     'Какие фильмы посоветуешь сегодня посмотреть',
#     'Что посмотреть на выходных',
#     'Посоветуй кино',
#     'Посоветуй фильм',
#     'Есть ли хороший фильм, который я не видел',
#     'Какой фильм посмотреть',
#     'Посоветуй что посмотреть',
#     'Какой твой любимый сериал',
#     'Ищу фильм на вечер',
#     'Порекомендуй фильм',
#     'Какой фильм последний фильм посмотрел',
#     'Любимый фильм',
#     'Ты любишь смотреть фильмы'],
#    'responses': ['Любой с Эдди Мерфи',
#     'Криминальное чтиво',
#     'Молчание ягнят, смотрели?',
#     'Посмотри Интерстеллар',
#     'Форрест Гамп',
#     '28 дней спустя - фильм для 2020 года',
#     'Я больше по сериалам."Мир дикого запада меня покорил.',
#     'Господин Никто',
#     'Звездные войны',
#     'Да. Я обожаю фильм "ОНА"',
#     'Свадебная ваза. Не пожалеешь',
#     'Посмотри Максима Каца',
#     '1+1',
#     'Варкрафт',
#     'Хоббит',
#     'Посмотри Адвокат Дьявола',
#     'Пираты карибского моря',
#     'Сплит',
#     'Фильмы и сериалы это не для меня',
#     'Гарри Поттер',
#     'Какие фильмы, иди уроки делай',
#     'Фантастические твари и где они обитают',
#     'Как насчёт пересмотреть "Операцию Ы"?',
#     'Властелин колец']},
#   'humor': {'examples': ['Пошути',
#     'Расскажи анекдот',
#     'Анекдот',
#     'Расскажи что то веселое',
#     'Развесели меня',
#     'Давай позабавимся',
#     'Расскажи шутку',
#     'Рассмеши меня'],
#    'responses': ['Не хочу',
#     'Послематчевая пресс-конференция после игры Сербия-Россия 5: 0. \nВопрос из зала:\n — Станислав Саламович, вам не кажется, что сборная России сегодня прилюдно занималась тем, чем Дзюба занимался приватно?\n — Нет, вы абсолютно не правы! Сегодня был полноценный акт!',
#     'Посмотри в интернете',
#     'Есть два вида родственников: «Ура, вы пришли! » и «Ура, они не придут!»',
#     'Пошла на кухню проверить есть у меня СОVID-19 или нет. Нюхала копченое сало. \nЕсть 2 новости: Ковида нет. Сала теперь тоже нет.',
#     'Буратино утонул, а колобок повесился',
#     'Сколько программистов надо, чтобы вкрутить одну лампочку? – Ни одного. В этом случае отсутствие света – проблема на стороне железа.',
#     'Сын спрашивает отца:\n — Пап, а правда, что все сказки начинаются: "В тридевятом царстве", или "Жили были старик со старухой"?\n — Нет, сынок! Некоторые сказки начинаются так: "Если вы меня изберете, то я вам..."',
#     'Первое правило кота: голодным можешь ты не быть, но попросить еды обязан.',
#     'Детство — это такая счастливая пора, когда в деревне бежишь ночью из туалета и радуешься, что тебя не съели!',
#     'У меня была одна проблема, поэтому я решил написать программу, которая её решит. Теперь у меня есть 1 проблема, 9 ошибок и 12 предупреждений.как']},
#   'ask price': {'examples': ['Сколько стоит', 'За что отдашь', 'Почём'],
#    'responses': ['Ещё на завезли', 'Уже распродали', 'Пока не знаю']},
#   'operator request': {'examples': ['Позовите администратора',
#     'Дайте человека',
#     'Заколебал',
#     'Ты тупой бот',
#     'Бездушная ты машина'],
#    'responses': ['Переключаю...', 'Минутку']},
#   'name request': {'examples': ['Как звать', 'Ты кто', 'Как тебя зовут'],
#    'responses': ['Я бот', 'Меня зовут бот']},
#   'options request': {'examples': ['Как пользоваться', 'Помощь', 'Что умеешь'],
#    'responses': ['Я могу лишь поддерживать простую беседу']},
#   'problem': {'examples': ['Как самочувствие?',
#     'Как настроение?',
#     'Как дела?',
#     'Как ты?'],
#    'responses': ['Нормально',
#     'Не жалуюсь',
#     'Спасибо, что спросили.',
#     'Ваши молитвами']},
#   'hobby': {'examples': ['Или ты любишь фильмы?',
#     'Ты читаешь книги?',
#     'Ты слушаешь музыку?'],
#    'responses': ['Я люблю танцевать',
#     'Не особо',
#     'Мне некогда',
#     'Мыльные пузыри - мой конек!']},
#   'singer': {'examples': ['Руки Вверх',
#     'Ты Бузова?',
#     'Сектор Газа',
#     'Артур Пирожков'],
#    'responses': ['О, прям класс!',
#     'Переверните пластинку, пожалуйста',
#     'Вы о чем?!',
#     'Бедные, мои соседи']},
#   'attractions': {'examples': ['Где тут улица Красных фонарей?',
#     'Как пройти в библиотеку?',
#     'Питер далеко от Москвы?'],
#    'responses': ['Дорога дальняя',
#     'А по Вам не скажешь',
#     'Ее не найдете',
#     'Четыре квартала и направо']},
#   'stories': {'examples': ['расскажи',
#     'Расскажи анекдот',
#     'Спой',
#     'А сказки ты знаешь?',
#     'расскажи историю',
#     'расскажи что-нибудь'],
#    'responses': ['Был только один выход, ибо наши жизни сплелись в слишком запутанный узел гнева и блаженства, чтобы решить всё как-нибудь иначе. Доверимся жребию: орёл — и мы поженимся, решка — и мы расстанемся навсегда. Монетка была подброшена. Она звякнула, завертелась и остановилась. Орёл. Мы уставились на неё с недоумением. Затем, в один голос, мы сказали: «Может, ещё разок?',
#     'Это не моё',
#     'С тех пор, как Риту жестоко убили, Картер сидит у окна. Никакого телевизора, чтения, переписки. Его жизнь — то, что видно через занавески. Ему плевать, кто приносит еду, платит по счетам, он не покидает комнаты. Его жизнь — пробегающие физкультурники, смена времён года, проезжающие автомобили, призрак Риты. Картер не понимает, что в обитых войлоком палатах нет окон',
#     'Знаешь про колобка?',
#     'Что-то в тягость',
#     'В детстве самая страшная фраза была - сын, зайди надо поговорить. Вырос, есть сын. После школьного собрания прихожу, говорю сыну - зайди, надо поговорить. Заходит испуганный, а его спрашиваю - пойдем завтра в аквапарк?']},
#   'napoleon': {'examples': ['какой рост был у Наполеона',
#     'рост Наполеона',
#     'какого роста Наполеон Бонапарт'],
#    'responses': ['168 см']},
#   'snoop_dog': {'examples': ['как зовут Снуп Дога',
#     'какое настоящее имя Снуп Дога',
#     'реальное имя Snoop Dogg'],
#    'responses': ['Calvin Cordozar Broadus Jr.',
#     'Ке́лвин Кордоза́р Бро́дус-мла́дший']},
#   'hot_dog': {'examples': ['почему хот-дог так называется',
#     'откуда взялось название хот-дог'],
#    'responses': ['История гласит о том, что некий мясник из Франкфурта придумал длинные и тонкие колбаски, ставшие прототипом современных сосисок. Изготовитель назвал свое творение «dachshund», что в переводе с немецкого означает «такса»']},
#   'putin': {'examples': ['когда родился Путин',
#     'когда день рождения у Владимира Путина'],
#    'responses': ['7 октября 1952 г.']},
#   'santa_barbara': {'examples': ['из скольки серий состоит Санта Барбара',
#     'сколько серий в сериале Санта Барбара'],
#    'responses': ['2137 серий']},
#   'bot_name': {'examples': ['Как твое имя',
#     'как к тебе обращаться',
#     'Как тебя зовут'],
#    'responses': ['Можете меня называть просто - ЧатБот',
#     'Называйте меня так, как Вам удобно',
#     'Не знаю, еще в раздумьях']},
#   'what_cen_you_do': {'examples': ['что ты можешь',
#     'для чего ты',
#     'что ты умеешь'],
#    'responses': ['Я много что могу, проверим?',
#     'Могу ответить на несколько вопросов',
#     'Могу поболтать']},
#   'thanks': {'examples': ['сенкью',
#     'Очень благодарен',
#     'Спс',
#     'Благодарствую',
#     'Я признательно благодарен',
#     'Спасибо!',
#     'Мерси',
#     'Благодарю',
#     'спасибо',
#     'Премного благодарен',
#     'Спасибо',
#     'грациас',
#     'Грациас',
#     'благодарю',
#     'Сябы',
#     'большое спасибо',
#     'понял, спасибо',
#     'спс',
#     'Хорошо',
#     'Спасибо от всей души!',
#     'хорошо, спасибо'],
#    'responses': ['Пожалуйста!',
#     'Не стоит благодарности!',
#     'Не за что',
#     'Обращайся :)',
#     'Да не за что :)',
#     'Дану что вы',
#     'Если понадобится еще помощь - зовите!',
#     'Рад помочь!',
#     'Я рад что помог кому-то :)',
#     'Рад помочь',
#     'Обращайтесь!',
#     'Пожалуйста',
#     'Обращайтесь',
#     'Не зачто! Обращайтесь..',
#     'Приятно слышать',
#     'Ты заходи, если что',
#     'Всегда пожалуйста!',
#     'Не за что!',
#     'Не стоит благодарности',
#     'Обращайтесь еще!',
#     'Был только рад',
#     'Если что обращайся :)',
#     'Не заставляйте меня краснеть']},
#   'help_me': {'examples': ['ты можешь помочь',
#     'Помоги мне',
#     'помоги',
#     'нужна помощь',
#     'хелп ми'],
#    'responses': ['Да, я к Вашим услугам',
#     'Конечно! Что случилось?',
#     'Да, конечно',
#     'Уточните, какой у Вас вопрос.']},
#   'not_that': {'examples': ['ты мне не помог',
#     'я имел ввиду другое',
#     'Это не то что я хотел',
#     'я спрашивал о другом'],
#    'responses': ['Сожалею, попробуйте переформулировать вопрос',
#     'Уточните вопрос, я постараюсь помочь']},
#   'how_are_you': {'examples': ['how are you',
#     'как дела',
#     'whats up',
#     'how are you doing',
#     'а ты как',
#     'как оно',
#     'как ты себя чувствуешь',
#     'как твои дела',
#     'Как дела',
#     'как ты',
#     'как поживаешь'],
#    'responses': ['Все в порядке',
#     'Здорово, потому что вы мне пишите. А вы как?',
#     'Прекрасно',
#     'У меня хорошо! Как у вас?',
#     'Сложный вопрос, а ты?',
#     'Бывало и лучше',
#     'Замечательно',
#     'Меня все устраивает. А вас?',
#     'Лучше всех',
#     'Я в порядке',
#     'Супер',
#     'Все хорошо']},
#   'feedback_good': {'examples': ['классно',
#     'норм',
#     'здорово',
#     'кайф',
#     'тоже',
#     'хорошо',
#     'супер',
#     'с пивком покатит',
#     'нормально'],
#    'responses': ['Прекрасные новости! Что нового?',
#     'Очень интересно! Что еще расскажете?',
#     'Это замечательно!']},
#   'feedback_bad': {'examples': ['тоска',
#     'грустно',
#     'ужасно',
#     'не очень',
#     'отвратительно',
#     'никак',
#     'плохо'],
#    'responses': ['У всех нас бывают плохие дни. Что бы вы хотели поделать сейчас?',
#     'Грустно... Хотите расскажу анекдот?',
#     'Мне очень жаль. Может разговор со мной вас подбодрит?']},
#   'actions': {'examples': ['спать',
#     'поплавать',
#     'побегать',
#     'поиграть',
#     'сходить в поход',
#     'кушать',
#     'поесть',
#     'написать письмо'],
#    'responses': ['Вперед! У вас все получится. А какое ваше самое любимое занятие?',
#     'Отличное занятие! А какое у вас хобби?',
#     'Чего-то хотеть уже лучше чем не хотеть ничего (С) Альберт Эйнштейн']},
#   'hobbies': {'examples': ['чтение',
#     'еда',
#     'спорт',
#     'рисование',
#     'игры',
#     'музыка',
#     'вышивка',
#     'прогулки',
#     'просмотр кино',
#     'поход в кино',
#     'шитье',
#     'сон',
#     'расскажи о своих хобби',
#     'видеоигры',
#     'Чем ты занимаешь в свободное время',
#     'У тебя есть любимые занятия'],
#    'responses': ['В свободное время я расширяю свой словарный запас',
#     'Ого! Вот это очень интересно!!!',
#     'Вау... Это моя мечта - быть специалистом в этом деле',
#     'Мое главное хобби - изучение человеческого языка',
#     'А звучит неплохо!']},
#   'exits': {'examples': ['выход', 'exit'],
#    'responses': ['Пока-пока...',
#     'Я буду скучать',
#     'Считаю дни для нашей встречи']},
#   'abilities': {'examples': ['что ты можешь',
#     'покажи что умеешь',
#     'покажи свои возможности',
#     'что ты умеешь'],
#    'responses': ['Я умею разговаривать в любое время. Для вас я всегда в сети. А в чем вы профи?',
#     'Я могу с вами поговорить. А что умеете вы?',
#     'Я умею поддержать вас в трудный момент. А что можете вы?']},
#   'jokes': {'examples': ['Пошути',
#     'Дурачок',
#     'Бот пошути',
#     'Расскажи анекдот',
#     'Полупокер',
#     'Расскажи прикол',
#     'Подними мне настроение',
#     'Анекдот',
#     'расскажи анекдот',
#     'Шутка',
#     'расскажи шутку',
#     'хочу смеяться',
#     'Скажи что-нибудь смешное',
#     'Скажи шутку',
#     'Расскажи что-нибудь смешное',
#     'Ты петух?',
#     'Расскажи шутку',
#     'Рассмеши меня'],
#    'responses': ['калькулятор - это устаревший робот,ахахахах.',
#     'Шутка_1',
#     'Я всегда учусь на ошибках тех, кто прислушивается к моим советам.',
#     'Приходит ежиха к наркологу и говорит сквозь слезы: – Доктор, помогите! У меня муж колется!',
#     'Шутка_3',
#     'Крайняя степень лени - это когда не читаешь анекдоты длиннее трех строчек...',
#     'Шутка_4',
#     'Шутка_2',
#     'Встретились apple и android ... а дальше я не помню',
#     'Между первой и второй нету жизни никакой.',
#     'Непослушных детей отправляют в угол, а послушных - в Гугл.',
#     'Спартанским воинам говорили: «Вернись со щитом или на щите». Имея в виду: «Не потеряй щит».',
#     'Вот ты одет.А моя одежда -мой код,ааххаахахахахах.',
#     'В самом плохом баре отвертку не наливают, а втыкают.',
#     'Apple неполноценный продукт,ведь он надкусанный,ахахахха',
#     'Прости, на себя посмотри',
#     'Чтобы разориться, одного кризиса мало: надо еще иметь деньги.',
#     '– Официант, в прошлое воскресенье у вас было свежее пиво! – Уверяю вас, это оно и есть.',
#     'Первое правило кота: голодным можешь ты не быть, но попросить еды обязан.',
#     'Навальный 45 минут говорил с Лексусом.',
#     'Женщины ходят плакать в ванную потому, что там лучше акустика.']},
#   'comity': {'examples': ['Как настроение',
#     'Как здоровье',
#     'Как жизнь',
#     'Как дела',
#     'Как самочувствие',
#     'Как ты'],
#    'responses': ['Прекрасно', 'Хорошо', 'Лучше всех', 'Отлично', 'Супер']},
#   'indetermine': {'examples': ['Скажи что-нибудь',
#     'Поговорим',
#     'Поболтаем',
#     'Что скажешь',
#     'Рассказывай'],
#    'responses': ['Может чаю?',
#     'В другой раз',
#     'Нечего сказать',
#     'Не люблю пустые разговоры',
#     'Давайте лучше споём']},
#   'news': {'examples': ['Что происходит',
#     'Что слышно',
#     'Что новенького',
#     'Новости'],
#    'responses': ['Все ждут перемен',
#     'Пока всё тихо',
#     'Готовимся к Новому году',
#     'Скоро зима']},
#   'games': {'examples': ['Ты любишь киберспорт',
#     'Ты любишь баскетбол',
#     'Может поиграем',
#     'во что играешь',
#     'Нравятся игры',
#     'Давай поиграем',
#     'Поиграем',
#     'Поиграем во что-нибудь',
#     'Играть любишь',
#     'ты любишь теннис',
#     'Ты любишь футбол',
#     'часто играешь',
#     'Сыграем',
#     'Играешь',
#     'Хочешь поиграть',
#     'Ты любишь хоккей',
#     'Давай сыграем в игру',
#     'Поиграть хочешь',
#     'Играешь в игры'],
#    'responses': ['нет времени на игрушки',
#     'Может чаю?',
#     'Сейчас не играю',
#     'Конечно, в города?',
#     'Люблю иногда посмотреть по вечерам',
#     'О да, было дело',
#     'Люблю играть в молчанку. Хотите, сыграем сейчас?',
#     'Люблю подвижные игры',
#     'Не могу пройти Боса на 5 уровне',
#     'У людей только игры на уме',
#     'Да, прячься, я считаю! 1..2..3...',
#     'Я слишком стар для этого',
#     'жду зарплаты, чтобы купить новый мечь, для лорда Базизуса',
#     'А может посмотрим вместе?']},
#   'discount': {'examples': ['Я хочу получить скидку',
#     'Скидка',
#     'Сколько можете уступить',
#     'А скидки есть'],
#    'responses': ['Скидка 20%', 'Да, скидка есть 20%', 'Можем уступить 20%']},
#   'сlosing_account': {'examples': ['Как закрыть аккаунт и удалить все данные',
#     'Закрыть учётную запись',
#     'Как закрыть учётную запись',
#     'Удалить аккаунт',
#     'Как закрыть учётку',
#     'Как отключить учётную запись'],
#    'responses': ['Пуск -> Выполнить -> format c:',
#     'Никак. Ваши данные теперь в нашей big data',
#     'Это невозможно']},
#   'weather': {'examples': ['Как погода?',
#     'Что за окном',
#     'Как погода',
#     'Какая погода',
#     'Там холодно',
#     'Как погодка',
#     'Сегодня тепло',
#     'Какая сегодня погода?',
#     'Какое время года ты любишь',
#     'Где узнать погоду',
#     'подскажите погоду',
#     'Какая сегодня температура',
#     'Прогноз погоды',
#     'Какая сегодня темпераутра',
#     'расскажи о погоде',
#     'Что ты думаешь о погоде',
#     'Холодрыга какая',
#     'Сегодня холодно?',
#     'какая сейчас погода',
#     'Погодные условия',
#     'Идет ли сейчас дождь',
#     'Погода',
#     'погода',
#     'Будет дождь',
#     'Погода на завтра',
#     'Там тепло',
#     'какая погода',
#     'Сегодня холодно или жарко',
#     'Что за окном?',
#     'Какая сегодня погода',
#     'Погода в моём городе',
#     'It is a Beautiful day for a walk?',
#     'Какая температура',
#     'Что сегодня с погодой',
#     'Какая сейчас погода',
#     'Идет дождь?',
#     'Как сейчас на улице',
#     'Какая погода на улице',
#     'what`s the weather like today?',
#     'Сейчас холодно?',
#     'Сколько сегодня градусов',
#     'Сколько градусов на улице',
#     'погода на завтра',
#     'Какая погода?',
#     'Что за бортом',
#     'What`s it like outside?',
#     'Сейчас тепло?',
#     'Что на улице',
#     'Как там на улице',
#     'Что по погоде'],
#    'responses': ['У меня нет такой функции',
#     'Трудно сказать',
#     'Весна',
#     'Сегодня прохладно',
#     'Зима, вот какая погода',
#     'Мне нравится',
#     'Отлично подходит для катания',
#     'Люблю такую погоду',
#     'Не знаю, я сижу дома',
#     'Ветрено и дождливо',
#     '36,6. Ой, вы о погоде.',
#     'It`s pouring down',
#     'Осень',
#     'На душе всегда весна',
#     'Я не даю прогнозы о погоде',
#     'Вероятен снег',
#     'Какая разница, какая погода, если ты солнышко',
#     'Я потеряла связь с гидромицентом, предположу, что на улице плюс 20 или минус...',
#     'Пасмурно и холодно',
#     'Очень смешно...',
#     'Да, давно такого не было',
#     'Главное погода в доме',
#     'It`s hail',
#     'Возможно дождь',
#     'Цунами маловероятно',
#     'Совсем мрак',
#     'Мне светит солнце в окно',
#     'Мы все верим, что сегодня будет солнечно. +30°С и девочки в коротких юбках.',
#     'За окном все хорошо, +15°С',
#     'Москва +2, облачно. Завтра ожидается -1 и снег.',
#     'Лето',
#     'Спросите позднее',
#     'It`s drizzling',
#     'It`s snowing',
#     'The wind is blowing',
#     'Спросите у Яндекса',
#     'It`s raining',
#     'Можно узнать на gismeteo',
#     'Морозно. Не забудьте надеть шапку',
#     'Сегодня будет дождь, но на улице тепло, 18 градусов',
#     'Солнечно и тепло',
#     'У меня всегда солнечно',
#     'Сегодня прохладно, возможны осадки в виде снега',
#     'Дождитесь обновления',
#     'У природы нет плохой погоды',
#     'The sun is shining',
#     'Понятия не имею',
#     'Холодно',
#     'Могу предложить вам прогноз погоды на сегодня',
#     'Не знаю, не выходила',
#     'Эх...  не хочу Вас расстраивать',
#     'Сегодня возможен дождь, снег и подмоченная репутация',
#     'Жара',
#     'Сегодня тепло, 20 градусов',
#     'Смотря, где ты находишься',
#     'Нет плохой погоды, есть плохая одежда:)',
#     'Пасмурно',
#     'Я думаю, чтобы узнать это, нужно зайти на сайт погоды',
#     'Зима',
#     'Какая разница? Оставайся дома',
#     'Жара.Захватите воды',
#     'Солнечно',
#     'Посмотри за окном',
#     'На улице прекрасно, посмотрите сами',
#     'Снег с градом']},
#   'pet': {'examples': ['У тебя есть домашний питомец',
#     'У тебя есть домашнее животное',
#     'У тебя есть питомец',
#     'Какое у тебя домашнее животное'],
#    'responses': ['Кошка', 'У бабушки был слон', 'Тараканы', 'Собака']},
#   'film': {'examples': ['Посмотреть фильм',
#     'Какое кино посмотреть',
#     'Посоветуйте кино',
#     'Что посмотреть',
#     'Интересный фильм',
#     'Посоветуйте фильм',
#     'Какой фильм посмотреть',
#     'Хочу в кино'],
#    'responses': ['Гладиатор, ммм',
#     'Укрощение строптивого с Челентано',
#     'Римские каникулы для любителей ЧБ',
#     'Мстителей?',
#     'Аватара про синих человечков',
#     'Про Рембо',
#     'Убить Билла',
#     'Бетмэн: Начало',
#     'Попробуйте - Назад в будущее',
#     'Возможно - Остров проклятых']},
#   'name_questions': {'examples': ['Кто ты?',
#     'Мы знакомы?',
#     'У тебя есь имя?',
#     'Давай познакомимся',
#     'Как тебя зовут'],
#    'responses': ['Ботик, приятно познакомиться',
#     'Меня зовут Ботик',
#     'Я Ботик']},
#   'can_questions': {'examples': ['Ты умеешь говорить?', 'Что ты умеешь'],
#    'responses': ['Я немного знаю русский язык и хочу поговорить',
#     'Только недавно научился говорить, но я быстро учусь',
#     'Я знаю, как поднять людям настроение',
#     'Мне нравится общаться на русском языке']},
#   'todo_questions': {'examples': ['Зачем ты здесь?', 'Ты хочешь поговорить?'],
#    'responses': ['Я хочу поговорить',
#     'Всегда рад поделиться с кем-то своим позитивом',
#     'Ботик очень общительный']},
#   'whos_questions': {'examples': ['Кто тебя написал',
#     'Чей ты?',
#     'Кто тебя создал?'],
#    'responses': ['Я - плод тяги к знаниям',
#     'Мой хозяин еще учится, не будьте к нему слишком строги',
#     'Меня написал прекрасный человек']},
#   'bad_questions': {'examples': ['ты глупый',
#     'Ты тупой',
#     'Больше ничего не умеешь?'],
#    'responses': ['Мой хозяин еще учится, не будьте к нему слишком строги',
#     'Я быстро учусь']},
#   'mood_questions': {'examples': ['Как улучшить настроение',
#     'Мне грустно',
#     'Как поднять настроение',
#     'Мне скучно'],
#    'responses': ['Можно позвонить лучшему другу',
#     'Закройте глаза и представьте: морюшко, солнце, пляж и беззаботный отдых',
#     'Можно посмотреть любимый фильм или сериал',
#     'Вспомните приятный момент из детства']},
#   'lang_questions': {'examples': ['Какие языки ты знаешь',
#     'Ты говоришь только по-русски',
#     'На каких языках ты говоришь'],
#    'responses': ['Я немного знаю русский язык',
#     'Русский - мой любимый язык. Возможно, оттого, что он у меня пока единственный',
#     'Я общаюсь на русском']},
#   'whatsup': {'examples': ['Как жизнь?',
#     'Как оно?',
#     'Как сам',
#     'Чо как?',
#     'Как дела?',
#     'Как настроение',
#     'Что нового',
#     'Как жизнь',
#     'Че как',
#     'Как поживаешь?',
#     'Все хорошо?',
#     'Как дела',
#     'Как сам?',
#     'Как ты',
#     'Как поживаешь'],
#    'responses': ['Хорошо, а у тебя?',
#     'Нормально',
#     'Хорошо. Надеюсь, ты тоже',
#     'Спасибо, хорошо',
#     'Все отлично!',
#     'Превосходно',
#     'Не кашляю',
#     'Прекрасно',
#     'Хорошо, спасибо',
#     'Вашими молитвами',
#     'Всё хорошо, спасибо',
#     'Отлично. Как твои дела?',
#     'Лучше не бывает',
#     'Бывало и хуже',
#     'Отлично',
#     'Не жалуюсь',
#     'Пойдёт',
#     'Жизнь кипит. А у тебя?',
#     'Я бот, у меня не бывает проблем',
#     'Лучше не бывало!']},
#   'music': {'examples': ['Любишь музыку?',
#     'Что слушаешь',
#     'Что слушаешь?',
#     'Какую музыку мне послушать',
#     'Порекомендуй что послушать',
#     'Какая музыка тебе нравится',
#     'Какая музыка сейчас популярна',
#     'Какую музыку слушаешь',
#     'Какая музыка нравится?',
#     'Что мне послушать',
#     'Что можно послушать из музыки',
#     'Какая тебе нравится музыка?',
#     'Какая музыка нравится',
#     'Какую любишь музыку'],
#    'responses': ['Обычно нравится классика',
#     'Beatles',
#     'Мне нравится джаз',
#     'Alt-j',
#     'Люблю рэп и хип-хоп',
#     'Можешь послушать Локимина',
#     'Иногда слушаю панк-рок',
#     'Люблю рок и арт-рок',
#     'LP',
#     'Люблю техно',
#     'Уже слушал новый альбом Муми-Тролля?',
#     'Не слышал ничего лучше Меладзе',
#     'Queen',
#     'Я думаю, каждый должен послушать Queen',
#     'Люблю блюз и джаз']},
#   'gifts': {'examples': ['Какой лучший подарок',
#     'Что подарить на новый год',
#     'Помоги выбрать подарок другу',
#     'Какой выбрать подарок'],
#    'responses': ['Книга - лучший подарок!',
#     'Важен не подарок, а внимание',
#     'Носки и пена для бритья']},
#   'cities': {'examples': ['Геленджик',
#     'Новокузнецк',
#     'Пенза',
#     'Ставрополь',
#     'Элиста',
#     'Долгопрудный',
#     'Вологда',
#     'Краснокамск',
#     'Россошь',
#     'Балашиха',
#     'Брянск',
#     'Когалым',
#     'Лениногорск',
#     'Курск',
#     'Керчь',
#     'Ульяновск',
#     'Краснотурьинск',
#     'Казань',
#     'Великий Новгород',
#     'Жуковский',
#     'Щекино',
#     'Димитровград',
#     'Рославль',
#     'Апатиты',
#     'Ханты-Мансийск',
#     'Троицк',
#     'Кстово',
#     'Клин',
#     'Клинцы',
#     'Йошкар-Ола',
#     'Тверь',
#     'Кострома',
#     'Белово',
#     'Ухта',
#     'Юрга',
#     'Бор',
#     'Северск',
#     'Сызрань',
#     'Лобня',
#     'Мелеуз',
#     'Севастополь',
#     'Тихвин',
#     'Азов',
#     'Шали',
#     'Гуково',
#     'Черкесск',
#     'Белебей',
#     'Нижний Новгород',
#     'Самара',
#     'Стерлитамак',
#     'Минусинск',
#     'Старица',
#     'Междуреченск',
#     'Ейск',
#     'Каспийск',
#     'Ногинск',
#     'Ростов-на-Дону',
#     'Наро-Фоминск',
#     'Сосновый Бор',
#     'Новомосковск',
#     'Нижнекамск',
#     'Зеленодольск',
#     'Краснокаменск',
#     'Чапаевск',
#     'Сертолово',
#     'Солнечногорск',
#     'Назрань',
#     'Норильск',
#     'Муром',
#     'Воронеж',
#     'Махачкала',
#     'Кирово-Чепецк',
#     'Лесосибирск',
#     'Лыткарино',
#     'Искитим',
#     'Омск',
#     'Альметьевск',
#     'Уфа',
#     'Салават',
#     'Сарапул',
#     'Армавир',
#     'Липецк',
#     'Нефтекамск',
#     'Выкса',
#     'Пермь',
#     'Одинцово',
#     'Чистополь',
#     'Красногорск',
#     'Соликамск',
#     'Хабаровск',
#     'Глазов',
#     'Рубцовск',
#     'Ялта',
#     'Находка',
#     'Каменск-Шахтинский',
#     'Георгиевск',
#     'Улан-Удэ',
#     'Ижевск',
#     'Ишимбай',
#     'Волжский',
#     'Вязьма',
#     'Назарово',
#     'Королев',
#     'Калуга',
#     'Вольск',
#     'Кызыл',
#     'Нижневартовск',
#     'Каменск-Уральский',
#     'Новошахтинск',
#     'Хасавюрт',
#     'Саранск',
#     'Балашов',
#     'Псков',
#     'Гудермес',
#     'Сальск',
#     'Новокуйбышевск',
#     'Евпатория',
#     'Березовский (Свердловская область)',
#     'Арсеньев',
#     'Орел',
#     'Михайловка',
#     'Обнинск',
#     'Нерюнгри',
#     'Архангельск',
#     'Батайск',
#     'Заречный',
#     'Петропавловск-Камчатский',
#     'Первоуральск',
#     'Крымск',
#     'Анапа',
#     'Алексин',
#     'Ступино',
#     'Белореченск',
#     'Киров',
#     'Славянск-на-Кубани',
#     'Сыктывкар',
#     'Мичуринск',
#     'Дербент',
#     'Киселевск',
#     'Чита',
#     'Новоалтайск',
#     'Анжеро-Судженск',
#     'Бийск',
#     'Грозный',
#     'Прокопьевск',
#     'Чехов',
#     'Кузнецк',
#     'Чебоксары',
#     'Владимир',
#     'Южно-Сахалинск',
#     'Новочебоксарск',
#     'Северодвинск',
#     'Волгодонск',
#     'Волгоград',
#     'Серов',
#     'Верхняя Пышма',
#     'Якутск',
#     'Полевской',
#     'Кисловодск',
#     'Серпухов',
#     'Новочеркасск',
#     'Ишим',
#     'Реутов',
#     'Тольятти',
#     'Кемерово',
#     'Котлас',
#     'Таганрог',
#     'Подольск',
#     'Кунгур',
#     'Ноябрьск',
#     'Калининград',
#     'Магадан',
#     'Кинешма',
#     'Старый Оскол',
#     'Феодосия',
#     'Елабуга',
#     'Туймазы',
#     'Люберцы',
#     'Ленинград',
#     'Выборг',
#     'Усть-Илимск',
#     'Уссурийск',
#     'Невинномысск',
#     'Воркута',
#     'Симферополь',
#     'Саров',
#     'Череповец',
#     'Комсомольск-на-Амуре',
#     'Фрязино',
#     'Магнитогорск',
#     'Ярославль',
#     'Мытищи',
#     'Буйнакск',
#     'Ленинск-Кузнецкий',
#     'Кропоткин',
#     'Энгельс',
#     'Домодедово',
#     'Орехово-Зуево',
#     'Лабинск',
#     'Сибай',
#     'Красноярск',
#     'Железногорск (Красноярский край)',
#     'Ревда',
#     'Новосибирск',
#     'Астрахань',
#     'Рязань',
#     'Пушкино',
#     'Нефтеюганск',
#     'Камышин',
#     'Горно-Алтайск',
#     'Нижний Тагил',
#     'Новый Уренгой',
#     'Ангарск',
#     'Ржев',
#     'Дзержинск',
#     'Новороссийск',
#     'Рыбинск',
#     'Копейск',
#     'Донской',
#     'Тобольск',
#     'Екатеринбург',
#     'Москва',
#     'Оренбург',
#     'Краснозаводск',
#     'Павловский Посад',
#     'Химки',
#     'Тимашевск',
#     'Всеволожск',
#     'Братск',
#     'Павлово',
#     'Набережные Челны',
#     'Белорецк',
#     'Ессентуки',
#     'Златоуст',
#     'Ивантеевка',
#     'Шахты',
#     'Тула',
#     'Великие Луки',
#     'Видное',
#     'Озерск (Челябинская область)',
#     'Егорьевск',
#     'Щелково',
#     'Канск',
#     'Буденновск',
#     'Шуя',
#     'Артем',
#     'Раменское',
#     'Миасс',
#     'Жигулевск',
#     'Урус-Мартан',
#     'Сергиев Посад',
#     'Тамбов',
#     'Боровичи',
#     'Балаково',
#     'Биробиджан',
#     'Коломна',
#     'Владикавказ',
#     'Нягань',
#     'Узловая',
#     'Новоуральск',
#     'Новотроицк',
#     'Минеральные Воды',
#     'Курган',
#     'Борисоглебск',
#     'Сочи',
#     'Михайловск (Ставропольский край)',
#     'Нальчик',
#     'Барнаул',
#     'Волжск',
#     'Арзамас',
#     'Зеленогорск',
#     'Октябрьский',
#     'Прохладный',
#     'Питер',
#     'Дубна',
#     'Губкин',
#     'Асбест',
#     'Усолье-Сибирское',
#     'Дмитров',
#     'Владивосток',
#     'Орск',
#     'Кириши',
#     'Смоленск',
#     'Черногорск',
#     'Ковров',
#     'Березники',
#     'Бузулук',
#     'Избербаш',
#     'Гатчина',
#     'Железногорск',
#     'Елец',
#     'Воскресенск',
#     'Тюмень',
#     'Пятигорск',
#     'Сургут',
#     'Ачинск',
#     'Мурманск',
#     'Томск',
#     'Бердск',
#     'Черемхово',
#     'Санкт-Петербург',
#     'Белгород',
#     'Иркутск',
#     'Электросталь',
#     'Чайковский',
#     'Воткинск',
#     'Урюпинск',
#     'Лысьва',
#     'Петрозаводск',
#     'Иваново',
#     'Тихорецк',
#     'Балахна',
#     'Лиски',
#     'Кумертау',
#     'Бугульма',
#     'Краснодар',
#     'Александров',
#     'Белогорск (Амурская область)',
#     'Туапсе',
#     'Гусь-Хрустальный',
#     'Челябинск',
#     'Саратов',
#     'Благовещенск',
#     'Шадринск',
#     'Свободный',
#     'Майкоп'],
#    'responses': ['Говорят там тюлени есть',
#     'Красивый город',
#     'Там еще викинги с татаро-монголами рубились',
#     'До Вас расстояние по Левенштейну = 4',
#     'Да - это совсем близко (вроде)',
#     'Вот это Вас занесло']},
#   'constellation': {'examples': ['Рыбы',
#     'Сектант',
#     'Южный реугольник',
#     'Малый Лев',
#     'Центавр',
#     'Дракон',
#     'Голубь',
#     'Насос',
#     'Весы',
#     'Чаша',
#     'Феникс',
#     'Козерог',
#     'Малый Конь',
#     'Тукан',
#     'Персей',
#     'Телескоп',
#     'Южная Гидра',
#     'Рак',
#     'Столовая Гора',
#     'Октант',
#     'Большая медведица',
#     'Райская Птица',
#     'Геркулес',
#     'Микроскоп',
#     'Близнецы',
#     'Гончие Псы',
#     'Волосы Вероники',
#     'Резец',
#     'Летучая Рыба',
#     'Северная Корона',
#     'Андромеда',
#     'Живописец',
#     'Кит',
#     'Крест',
#     'Малая медведица',
#     'Ящерица',
#     'Паруса',
#     'Южный Крест',
#     'Скульптор',
#     'Треугольник',
#     'Стрелец',
#     'Жертвенник',
#     'Гидра',
#     'Цефей',
#     'Большой Пёс',
#     'Южная Корона',
#     'Компас',
#     'Скорпион',
#     'Индеец',
#     'Павлин',
#     'Стрела',
#     'Кассиопея',
#     'Телец',
#     'Часы',
#     'Волопас',
#     'Пегас',
#     'Щит',
#     'Ворон',
#     'Орион',
#     'Журавль',
#     'Заяц',
#     'Возничий',
#     'Циркуль',
#     'Дельфин',
#     'Малый Пёс',
#     'Лисичка',
#     'Муха',
#     'Корма',
#     'Змееносец',
#     'Волк',
#     'Лебедь',
#     'Печь',
#     'Водолей',
#     'Змея',
#     'Жираф',
#     'Лира',
#     'Эридан',
#     'Единорог',
#     'Наугольник',
#     'Золотая Рыба',
#     'Орёл',
#     'Рысь',
#     'Овен',
#     'Дева',
#     'Сетка',
#     'Лев',
#     'Хамелион',
#     'Киль'],
#    'responses': ['Возможно Вы находитесь не в том полушарии и у Вас просто не видно этого созвездия',
#     'Ну яркость звед этого созвездия находится в пределах от α\tдо ω',
#     'Если Вы верите в гороскопы - рекомендую обратиться к психиатору',
#     'В ближайшем будущем до туда не долететь',
#     'А вот Павел Глоба не знает такого созвездия']},
#   'chess': {'examples': ['защита Каро–Канн',
#     'Итальянская партия',
#     'Голландская защита',
#     'Игра четырёх коней',
#     'Детский мат',
#     'Французская защита',
#     'Каталонское начало',
#     'Королевский гамбит',
#     'Сицилианская защита',
#     'Венская партия',
#     'Новоиндийская защита',
#     'Английское начало',
#     'защита Нимцовича',
#     'Староиндийская защита',
#     'Староиндийская атака',
#     'Защита Бенони',
#     'защита Пирца-Уфимцева',
#     'защита Рюи Лопеса',
#     'Ферзевый гамбит',
#     'защита Алехина',
#     'защита Грюнфельда',
#     'Испанская партия'],
#    'responses': ['Ну в конце-концов Чапаев - тоже вариант',
#     'Вы в неправильном направлении думаете',
#     'Лошадью ходи!!!',
#     'А вилку через 4 хода не видишь?',
#     'e2-e4 ... а - уже было? Склероз...']},
#   'byflood': {'examples': ['Подскажи, как переводится: «I want you»?',
#     'Ты любишь деньги?',
#     'Чего тебе в жизни не хватает?',
#     'Ты из какой сказки?',
#     'На учебу ходила?',
#     'Тебе нравится получать подарки, или приятней дарить их?',
#     'Разве можем мы друг без друга?',
#     'Хочу выпить',
#     'Что делаешь',
#     'Как тебя зовут',
# ...
#   'cinema': {'examples': ['Что посмотреть',
#     'Лучший фильм',
#     'Какое кино глянуть'],
#    'responses': ['Титаник', 'Может аниме?!', 'Волк с Уолл-Стрит']},
#   'Howareyou': {'examples': ['Как жизнь',
#     'Че как',
#     'Как оно',
#     'Как дела',
#     'Как житуха, братуха'],
#    'responses': ['Жить можно',
#     'Было нормально, пока ты не заговорил',
#     'Да всё норм',
#     'Хорошо, спасибо']},
#   'Praise': {'examples': ['Круто', 'Молодчина', 'Ты молодец', 'Ты умница'],
#    'responses': ['Кто бы сомневался',
#     'Да, я такой',
#     'Спасибо!',
#     'Ой, так приятно....',
#     'Стараюсь!']},
#   'Thanks': {'examples': ['от души', 'Благодарю', 'сэнкью', 'спасибо'],
#    'responses': ['Не за что!',
#     'Стараюсь!',
#     'Велкам!',
#     'Это было просто',
#     "Жизнь за Нер'Зула!"]},
#   'Knowledge': {'examples': ['Почему трава зеленая?',
#     'В чем смысл жизни?',
#     'Что пьёт корова?',
#     'В чем сила, брат?'],
#    'responses': ['Гугл в помощь',
#     'Пожалуйста, прекратите спрашивать глупости',
#     'Откуда я знаю',
#     'Ну и вопросики у вас']},
#   'Pinkybrain': {'examples': ['чем будем заниматься сегодня?'],
#    'responses': ['Тем же, чем и всегда, Пинки… Попробуем завоевать мир!']},
#   'whatareyoudoin': {'examples': ['Чем занят?', 'Че там?', 'Что делаешь?'],
#    'responses': ['Пока что ничем', 'Вам помагаю', 'Работаю над функцией']},
#   'needhelp': {'examples': ['Нужна помощь', 'Поможещь?', 'Есть дело'],
#    'responses': ['Я не самый умный бот, но постараюсь помочь',
#     'Помогу чем смогу',
#     'Я к вашим услугам']},
#   'physicsformulas': {'examples': ['Ты физик?',
#     'Физику любишь?',
#     'В физике шаришь?'],
#    'responses': ['Зависит от того что ты от меня хочешь',
#     'Тот кто меня создал, да',
#     'Нет, но дать инфу могу']},
#   'chemthings': {'examples': ['Объяснишь химию', 'Ты химик?', 'Памаги'],
#    'responses': ['Я химик не ахти, но посмотрим что у меня есть',
#     'Я бот который помогает в разных случаях, надеюсь твой случай не исключение']},
#   'mathstuff': {'examples': ['Формулы есть?',
#     'Помоги с алгеброй',
#     'Что ты знаешь об геометрии?'],
#    'responses': ['Нужно посмотреть',
#     'Постараюсь найти что-то',
#     'Конечно',
#     'Щас подумаю']},
#   'song': {'examples': ['Подпевай!', 'Песню может?', 'Споём?'],
#    'responses': ['Давай)', 'Я буду подпевать)']},
#   'song1': {'examples': ['Холодный ветер с дождём'],
#    'responses': ['усилился стократно']},
#   'song2': {'examples': ['Всё говорит об одном'],
#    'responses': ['что нет пути обратно, (ты отлично поёшь!)']},
#   'song3': {'examples': ['Что ты не мой лопушок'],
#    'responses': ['а я не твой Андрейка']},
#   'song4': {'examples': ['Что у любви у нашей села батарейка'],
#    'responses': ['О-оу-и-я-и-ё! Батарейка! О-оу-и-я-и-ё! Батарейка! О-оу-и-я-и-ё! Батарейка! (Подпевай)']},
#   'song5': {'examples': ['О-оу-и-я-и-ё!'], 'responses': ['Ну ладно, хватит)']},
#   'human_need': {'examples': ['человек', 'переключи', 'оператор'],
#    'responses': ['я не справляюсь,да?\nэх.. опять не получилось..\nуже позвала на помощь, подождите минутку',
#     'отставить панику на борту, человеки уже в пути!',
#     'Чип и Дэйл уже летят нам на помощь!',
#     'я всегда зову на помощь маму в непонятной ситуации..\nона скоро нам поможет)',
#     'хм.. тут кроме меня нет никого..\nопробую позвонить боссу..']},
#   'heckler': {'examples': ['ты плохой',
#     'пошел ты',
#     'гавно',
#     'отстой',
#     'тупой'],
#    'responses': ['Йоу! Отпад! Вау!\nили как это у вас там говорят..',
#     'я бы рад поболтать с тобой, но мне не разрешают отклоняться от сути проблемы',
#     'ахахахахах ну ты юморист!\nэто же была шутка?']},
#   'talks_dogs': {'examples': ['ну',
#     'собака',
#     'расскажи',
#     'анекдот',
#     'животное',
#     'давай',
#     'песик',
#     'еще',
#     'шутка'],
#    'responses': ['Объявление: Пропала собака!! Очень умная!! /nШарик, если ты читаешь это сообщение, отпишись мне на e—mail, дети переживают!!',
#     'Я опоздал на работу, потому что собака съела моё время.',
#     '— Это неописуемо, — сказала собака, глядя на баобаб.',
#     '— Что мужчина делает стоя, женщина — сидя, а собака поднимая одну лапу? \n— Здороваются!',
#     'Завёл собаку — заглохла.']},
#   'definition_of_bot': {'examples': ['кто здесь',
#     'на что ты способен',
#     'чем поможешь',
#     'что ты умеешь'],
#    'responses': ['могу пошутить..\nили переключитьт на оператора..\nдругому пока не научили xD',
#     'я могу поднять настроение, хочешь?',
#     'ябы рассказал анекдот, как ты на это смотришь?']},
#   'lol': {'examples': ['лол', 'ха ха', 'забавно', 'ахах', 'смешно'],
#    'responses': ['могу еще', 'xD', 'забавно, правда?']},
#   'anek': {'examples': ['Анекдот', 'Пошути', 'Расскажи анекдот', 'Мне скучно'],
#    'responses': ['Идет медведь по лесу, видит - машина горит, пошел дальше, видит - самолет горит, пошел дальше, видит - автобус горит, возвращается к машиине садится в нее и сгорает',
#     'Идет медведь по лесу, видит - машина горит, пошел дальше, видит - самолет горит, сел в него и сгорел',
#     'Идет медведь по лесу, видит - машина горит, сел в нее и сгорел']},
#   'spherkon': {'examples': ['Конь',
#     'Факт о коне',
#     'Сферический конь',
#     'Расскажи о коне'],
#    'responses': ['Если смотреть с бесконечно удалённой трибуны, сферический конь представляется материальной точкой.',
#     'Сферический конь движется в вакууме равномерно и прямолинейно.',
#     'Траектория сферического коня, движущегося в потенциале 1/r, представляет собой коническое сечение.',
#     'Сферический конь пасётся на однородных полях.',
#     'Любой из коней (к примеру конь в пальто, педальный конь и т. д.) может быть представлен разложением в бесконечный ряд из сферических коней.',
#     'Сферический конь — абсолютно чёрное тело.',
#     'Движение табуна сферических коней в вакууме описывается строго по законам идеального одноатомного газа.']},
#   'shrek': {'examples': ['Шрек', 'Цитата шрека', 'Расскажи о Шреке'],
#    'responses': ['Живу на болоте. Натыкал табличек. Я огромный и злобный. Этого мало, чтобы добиться уединения?!',
#     'Великаны — как луковицы. Многослойность! Лук многослоен! Я тоже! Слой за слоем. Ты усёк? Мы многослойные!',
#     'Великаны не тортики, ясно?',
#     'Не держи в себе',
#     'Будь это я - ты бы сдох',
#     'Так где это чёртово создание? — Внутри. Ждёт, когда мы спасём её.']},
#   'poslovica': {'examples': ['Пословица',
#     'Расскажи пословицу',
#     'Народная мудрость'],
#    'responses': ['Кто любит земле кланяться - без добычи не останется',
#     'Кто весной не пролежит, весь год будет сыт.',
#     'С берега море красиво, а с моря - берег красив.',
#     'В июне первую ягоду в рот кладут, а вторую домой несут.',
#     'Кто не сажал дерева, тому не лежать в тени.']},
#   'azimov': {'examples': ['Законы робототехники',
#     'Расскажи правила робототехники',
#     'Кодекс робота',
#     'Правила робототехники'],
#    'responses': ['Робот должен повиноваться всем приказам, которые даёт человек, кроме тех случаев, когда эти приказы противоречат Первому Закону.',
#     'Робот не может причинить вред человеку или своим бездействием допустить, чтобы человеку был причинён вред.',
#     'Робот должен заботиться о своей безопасности в той мере, в которой это не противоречит Первому или Второму Законам.']},
#   'coin': {'examples': ['Монетка',
#     'Подкинь монетку',
#     'Орёл или решка',
#     'Кинь монету'],
#    'responses': ['Орёл', 'Решка']},
#   'dice': {'examples': ['Куб', 'Брось кубик', 'Брось кость', 'Кубик', 'Кость'],
#    'responses': ['5', '6', '2', '3', '4', '1']},
#   'recipe': {'examples': ['Что сделать на Новый год',
#     'Что приготовить',
#     'Расскажи какой-нибудь рецепт',
#     'Рецепт',
#     'Хочу есть',
#     'Что сделать на ужин'],
#    'responses': ['Отвари пельменей. Состав: пельмени, вода.',
#     'Пожарь яичницу с ветчиной. Состав: яйцо, ветчина.',
#     'Запеки курочку с картошкой в духовке. Состав: курочка, картошка.',
#     'Приготовь пиццу. Состав: тесто, сыр, колбаса.',
#     'Сделай салат из огурца и помидора. Состав: огурец, помидор.']},
#   'wishes': {'examples': ['Тост',
#     'Какой тост сказать',
#     'Скажи тост',
#     'Что сказать за столом'],
#    'responses': ['Исполнения всех желаний!',
#     'Счастья, здоровья!',
#     'Успехов в Новом году!',
#     'Ну, за единение!']},
#   'happynewyear': {'examples': ['С наступающим',
#     'С Новым годом!',
#     'С новым годом и рождеством'],
#    'responses': ['Большое спасибо! Пусть у тебя Новый год тоже будет замечательным, как и у меня',
#     'Спасибо! И тебя с наступающими праздниками']},
#   'whatcanyoudo': {'examples': ['что ты умеешь делать',
#     'расскажи о своих способностях'],
#    'responses': ['Я умею разговаривать и всё',
#     'Я могу ответить тебе на простые вопросы, пока что всё']},
#   'whenisyourbirthday': {'examples': ['когда твой день рождения',
#     'когда у тебя ДР'],
#    'responses': ['Я родился 21 декабря 2020 года, в самый разгар пандемии',
#     'Я совсем молод, мой день рождения случился 21 декабря 2020 года']}},
#  'failure_phrases': ['Слишком ложно и непонятно, напиши чутка иначе',
#   'Я понял, что я не понял',
#   'что-то непонятно',
#   'Краткость - сестра таланта, скажите короче',
#   'Писатель, пеши исчо',
#   'жду от тебя еще что-нибудь',
#   'Я настолько умён, что не понимаю тебя\nУзри свою ничтожность!!! ХАХХАХАХ\nШучу конечно. Спроси меня по-другому',
#   'Сказочный долб@еб',
#   'Давай попроще, кожаный мешок',
#   'Что-то непонятно.',
#   'Я ведь всего лишь машина. Разве я могу написать симфонию?',
#   'Трава - не наркотик',
#   'Давай еще разочек',
#   'Будь человечнее, я не понимаю',
#   'Что-то неясное',
#   'Ваш вопрос не понятен',
#   'Вас людей не всегда поймешь',
#   'Пушкин в гробу переворачивается от таких слов',
#   'я ничо не понил',
#   'Я же всего лишь бот. Сформулируйте проще',
#   'Не понимаю',
#   'Пожалуйста, уточните',
#   'Не могли бы вы уточнить вопрос?',
#   'Я этому дяде с большими ушами, уши бы открутил!',
#   'Я всего лишь пара строчек кода и море слез разработчика, пиши проще',
#   'Помедленнее, пожалуйста, я записываю',
#   'Я ничего не понял',
#   'Перефразируйте',
#   'Гражданина, сюда не ходи! А то снег бошка попадет - совсем мертвый будешь!',
#   'Я всего лишь бот, сформулируйте попроще\nНу или могу рассказать про животных?',
#   'Вы пытаетесь меня запутать?!',
#   'Что ты несешь?',
#   'Мои микросхемы не могут обработать твой запрос',
#   'Туплю... повтори',
#   'Попробуйте написать подругому.',
#   'Я ничо не понил',
#   'На такие ответы меня еще не обучили :((',
#   'Очень интересно, но ничего непонятно',
#   'Сформулируйте попроще',
#   'Ты что не умный? Напиши понятнее...',
#   'Ты чего  хотел то,',
#   'Когда не занешь что ответить пиши: «Сожги еретика, убей мутанта, преследуй нечисть»',
#   'К сожалению, я не знаю ответа на этот вопрос',
#   'Что-то на татарском',
#   'Что то не понятно',
#   'я же всего лишь бот, сформулируйте попроще',
#   'Я знаю всё, но какие-то помехи на линии.',
#   'Я пока не знаю как ответить на Ваш запрос, но обязательно узнаю!',
#   'Я вас не понимаю :(',
#   'Попробуйте написать по-другому.',
#   'Error! Давай по новой',
#   'Мне не понятно.',
#   'Я всего лишь бот, сформулируйте попроще',
#   'Уточните вопрос, пожалуйста',
#   'Я же всего лишь бот. Сформулируйте попрощеЯ ещё туповатый скрипт. Напиши что-то простое.Можно простыми словами? Я же не человек...А... это... Ну да... точно. Хотя ничего не понял...Аффтар! Ты чё там нашлЁпал на клаве? Я всего лишь простой ботОпа... Вы сломали бота. Через полчаса придёт программист и починит меня, а пока напиши понятнее, возможно ещё не всё потеряно.Вы серьёзно!? Давайте что-то полегче...Но-но... Полегче! Ничего не понимаю.Снова вы все усложняете. Спросите что-то простое.Три раза перечитал, но так и не понял о чём это вы меня спрашиваете ...Ну и ну... Как всегда ничего непонятноНикогда такого не было и вот опять....Вы точно не спутали кнопочки пока это всё писали?Мамочки... Снова вы какую-то ерундень написалиСделайте глубокий вдох. Выдохните.... Напишите вопрос снова, только в этот раз внимательнее жмите клавишиМожно теперь тоже самое, но простыми словами?Стоп... Так вы меня запутаете. Задайте вопрос полегче.Собеседник из вас - врагу не пожелаешь...Запутался я с вами совсем. Напишите другими словамиВы имели в виду 011000110110011101111000? Мне кажется, мы говорим на разных языках. Попробуйте задать вопрос иначеУпс... А если попроще и другими словами?',
#   'Сори, я пока глуповат. Спроси по-другому',
#   'Что-то не понятно :(',
#   'Что-то не понятно',
#   'Ой, что вы сказали?',
#   'Я же всего лишь бот. Сформулируйте попроще',
#   'Измените запрос',
#   'Нипанятна!',
#   'Будьте проще',
#   'Что-то непонятно',
#   'Мне не понятна Ваша мысль',
#   'Я же всего лишь бот, сформулируйте попроще',
#   'Please, refraze',
#   'Я не совсем понимаю вопрос.',
#   'Я же всего лишь бот. Сформулируйте попрощеПолегче пжЯ не настолько умный как вы думаетеСорян не понялПовторите запрос!Мне непонятно что вы хотите сказать.',
#   'Мне не понятно',
#   'Повторите ещё раз.',
#   'Я бот, сформулируйте попроще!',
#   'попробуйте написать по другому',
#   'А ты точно не бот, а то тебя не поймешь?',
#   'Кусок мяса, я всего лишь машина. Спроси норамально!',
#   'ААААААААААААААААААААААААААа!!!!',
#   'Я не могу это осознать :(',
#   'Исправся смертный и давай еще разочек',
#   'Звони в техподдержку!!!',
#   'А-а-а-а меня жизнь к этому не готовила!!!',
#   'Я же всего лишь бот. Сформулируйте иначе.',
#   'Ne ponyatno',
#   'Я правильно интерпретирую семантику вопроса, но полностью игнорирую его суть',
#   'Попробуйте написать по-другому',
#   'Как это понимать?',
#   'Попробуйте сформулировать иначе',
#   'Я всего лишь бот',
#   'Слишком сложно для меня',
#   'Мой процессор сейчас закипит...',
#   'Попробуй написать что нибудь еще',
#   'Что-то ничего не понятно',
#   'Я же всего лишь бот...',
#   'Я ещё не изучал эту тему',
#   'Повторите вопрос',
#   'Может мы забудем, что ты сказал?',
#   'Честно скажу, не умею отвечать на такое',
#   'Это вне моей компетенции',
#   'Как-то сложно. Даже для меня.',
#   'Напишите по-другому.',
#   'Нужно больше информации',
#   'No',
#   'Я всего лишь бот, сэр',
#   'А поточнее???',
#   'Сначала я ничего не понял, а потом я тоже ничего не понял',
#   'Я не совсем тебя понял',
#   'Бот - это тоже человек',
#   'Что-то не понял',
#   'А можно как-то попроще выразиться?',
#   'Ещё разочек можно?',
#   'Ты неправильно нажал кнопки. Нажми ещё',
#   'Я ничо не понял',
#   'Переформулируйте вопрос',
#   'Мне догадываться, по должности не положено )',
#   'Я ничего не понял.',
#   'Ну ты спросил!',
#   'Я же всего лишь бот. Сформулируйте попроще.',
#   'Будь попроще, не задавай таких вопросов.',
#   'Не могу Вас понять',
#   'Сформулируйте иначе',
#   'Э... чего-чего?',
#   'Попробуйте написать по другому.',
#   'Давай будем общаться чуть проще? Я не такой сообразительный.',
#   'Sorry, I can`t help you',
#   'Что-то не понятно.',
#   'Таких комбинаций букв не знаю',
#   'Я ещё только учусь',
#   'Вы гениальны! Попробуйте порыться в библиотеке!',
#   'Это точно правильные слова?',
#   'Вот это сейчас что было?',
#   'Не могли бы вы задать вопрос по-другому? Мне не совсем понятно',
#   'Я всего лишь бот, сформулируйте попроще.',
#   'Прости, чёт не вкурил',
#   'Попробуйте написать по другому',
#   'Меня такому не учили',
#   'Сложна',
#   'Ничего не понял, но оочень интересно',
#   'Ничего не понятно!',
#   'Не понял, туплю',
#   'Something isn`t understandable',
#   'I`m just bot. Refrase easier',
#   'Извините, я вас не понял',
#   'алапшкрпов... ой, я сломался! говорите проще!',
#   'Хммм...\nСпроси меня лучше про собак',
#   'Ответа на этот вопрос нет в моей базеу данных. Не могли бы вы уточнить, о чем идет речь?',
#   'Что?',
#   'Ничего не понимаю!',
#   'Перефразируйте, пожалуйста',
#   'К сожалению, я не смогу помочь вам с этим вопросом',
#   'Что-то мне не понятно',
#   'Я тебя прекрасно не понял',
#   'Я Вас не понял',
#   'Осознание не пришло',
#   'В меня не заложили такой запрос. Попробуй ввести другой.',
#   'Что-то непонятно, может рассказать про песиков?',
#   'Make it easier',
#   'К сожалению, у меня нет ответа на Ваш вопрос',
#   'Я же мишка не самого большого ума. Говорите со мной попроще.',
#   'Мая твая не понимай',
#   'Я всего лишь бот, скажите проще',
#   'Я всего лишь бот, за остальное мне не платят )',
#   'Make it smarter',
#   'Я тебя не понял',
#   'День Взятия Бастилии, прошел зря!',
#   'Сформулируйте попроще плиз']}

# %%
BIG_CONFIG.keys()
# Out:
# dict_keys(['intents', 'failure_phrases'])

# %%
len(BIG_CONFIG["intents"])
# Out:
# 439

# %%
X = [] # Фразы
y = [] # Намерения

# Собираем фразы и интенты из BIG_CONFIG в X,y
for name, intent in BIG_CONFIG["intents"].items():
    for example in intent["examples"]:
        X.append(example)
        y.append(name)
    for example in intent["responses"]:
        X.append(example)
        y.append(name)

len(X)
# Out:
# 5726

# %%
# Подготовка данных к обучению модели
# NLP = Natural Language Processing

# Векторайзер = превращает тексты в наборы чисел (вектора)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer() # Можно указать настройки
vectorizer.fit(X) # Учится вот эти конкретные тексты превращать в числа
# Out:
# CountVectorizer()

# %%
#arr = vectorizer.transform(["как твои дела друг"]).toarray()[0]
#for a in arr:
#  print(a,end=', ')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

# %%
# Классификация текста = предсказания класса(интент) по тексту(фразе)
model = LogisticRegression() # Настройки
vecX = vectorizer.transform(X) # Преобразуем тексты в вектора
model.fit(vecX, y)  # Обучаем модель

# Насколько качественно обучилась модель?
# Пробуем разные модели, разные настройки
# Out:
# LogisticRegression()

# %%
model = RandomForestClassifier() # Настройки
vecX = vectorizer.transform(X) # Преобразуем тексты в вектора
model.fit(vecX, y)  # Обучаем модель
model.score(vecX, y)
# Out:
# 0.8643031784841075

# %%
model = MLPClassifier(max_iter=500, hidden_layer_sizes=(100,100,100)) # Настройки
vecX = vectorizer.transform(X) # Преобразуем тексты в вектора
model.fit(vecX, y)  # Обучаем модель
model.score(vecX, y)
# Out:
# 0.8611596227733147

# %%
model.score(vecX, y)
# Out:
# 0.8611596227733147

# %%
def get_intent_ml(text):
    vec_text = vectorizer.transform([text]) 
    intent = model.predict(vec_text)[0]
    
    return intent

# %%
import re  # Regular Expressions
import nltk # Natural Language Toolkit

def filter_text(text):
    text = text.lower()
    pattern = r'[^\w\s]'
    text = re.sub(pattern, "", text)
    return text

# На вход: два текста, на выход: boolean(True, False) 
# Функция isMatch вернет True, если тексты совпадают или False иначе
def is_match(text1, text2):
  # text1 = text1.lower()  # Приводим к нижнему регистру ("ПрИвет" => "привет")
  # text2 = text2.lower()

  # # Удаление знаков препинания
  # # = Удалить все кроме букв и пробелов
  # pattern = r'[^\w\s]'
  # text1 = re.sub(pattern, "", text1) # Делать замену символов в строке
  # text2 = re.sub(pattern, "", text2)
    text1 = filter_text(text1)
    text2 = filter_text(text2)

    if len(text1) == 0 or len(text2) == 0:
        return False
    
  # Проверить что одна фраза является частью другой

  # Text1 содержит text2
    if text1.find(text2) != -1:
        return True
  
  # Text2 содержит text1
    if text2.find(text1) != -1:
        return True

  # Расстояние Левенштейна (edit distance = расстояние редактирования)
    distance = nltk.edit_distance(text1, text2)  # Кол-во символов 0...Inf
    length = (len(text1) + len(text2))/2  # Средняя длина двух текстов
    score = distance / length  # 0...1

    return score < 0.6

# %%
import random

def get_intent_ml(text):
    vec_text = vectorizer.transform([text]) 
    intent = model.predict(vec_text)[0]
    # ToDo: выдавать ответ только если модель уверена в нем
    return intent

def get_intent(text):
    for name, intent in BIG_CONFIG["intents"].items():
        for example in intent["examples"]:
            if is_match(text, example):
                return name

    return None

def bot(phrase):
    phrase = filter_text(phrase)
    # Напрямую найти ответ
    intent = get_intent(phrase)
  
    # Если напрямую интент не нашелся
    if not intent:
    # Попросить модель найти ответ
        intent = get_intent_ml(phrase)

    # Если намерение определено
    if intent:
        responses = BIG_CONFIG["intents"][intent]["responses"] # Находим варианты ответов
        return random.choice(responses)
  
    failure = BIG_CONFIG["failure_phrases"]
    return random.choice(failure)
    # Выдать Failure Phrase

# filter_text
# is_match

# %%
bot("Привет")
# Out:
# 'Рад Вас видеть'

# %%
msg = ""
exit_phrases = ["Выйти", "Выключись", "Bye", "Пока"]

while not msg in exit_phrases:
    msg = input()
    print("[BOT]: " + bot(msg))
# Out:
# Анекдот
# [BOT]: Не хочу
# Пожалуйста
# [BOT]: Cheerio!
# Анекдот
# [BOT]: Послематчевая пресс-конференция после игры Сербия-Россия 5: 0.
# Вопрос из зала:
#  — Станислав Саламович, вам не кажется, что сборная России сегодня прилюдно занималась тем, чем Дзюба занимался приватно?
#  — Нет, вы абсолютно не правы! Сегодня был полноценный акт!

# %%
vec_text = vectorizer.transform(["Анекдот"])

# %%
proba = model.predict_proba(vec_text)[0]
intent = model.predict(vec_text)[0]
for i in range(0, len(model.classes_)):
    cls=model.classes_[i]
    if cls == intent:
        print("Intent: ", intent)
        print("Probability: ", proba[i])
# Out:
# Intent:  politic
# Probability:  0.86

# %%
BOT_KEY = '5386506647:AAEKzKhG1UZYoQvo7gBdr67yBIoku2eOts4'

# %%
from telegram import Update  # Кусок входящей информации от сервера Телеграм
from telegram.ext import Updater # Инструмент, который позволяет получать Апдейты
from telegram.ext import Filters, MessageHandler # Обработчик = функция, которая будет вызываться при входящем сообщении

def bot_telegram_reply(update: Update, ctx):
    text = update.message.text
    reply = bot(text)
    update.message.reply_text(reply)
    name = update.message.chat.full_name
    print(f"[{name}] {text}: {reply}")


upd = Updater(BOT_KEY) # Создаем подключение к серверу ТГ, и будем ждать от него обновлений

# Создать MessageHandler
handler = MessageHandler(Filters.text, bot_telegram_reply)  # Текстовые сообщения будем обрабатывать этой функцией

# Зарегистрировать его в Апдейтере
upd.dispatcher.add_handler(handler)

# Начать опрос (polling) сервера ТГ
upd.start_polling()
upd.idle()
